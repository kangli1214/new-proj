# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
#cifar10_adversarial accuracy based on PGD-50-10

adv_acc1=[0.7931,0.6700,0.5613,0.4818,0.4149,0.3668,0.3259,0.2712]
#2epsilon noise

adv_acc0=[0.7940,0.6748,0.5644,0.0000,0.0000,0.0000,0.0000,0.0000]
#0 noise

adv_acc2=[0.7918,0.6715,0.51618,0.4755,0.0000,0.0000,0.0000,0.0000]
#zerograd

adv_acc3=[0.7970,0.6722,0.5640,0.4817,0.4037,0.3394,0.0000,0.1930]
#multigrad

adv_acc4=[0.0901,0.0041,0.0008,0.0003,0.0000,0.0000,0.0001,0.0001]
#Not adversarial training with 2-epsilon noise

adv_acc5=[0.2267,0.0635,0.0219,0.0099,0.0037,0.0022,0.0011,0.0005]
#Not adversarial training with 4-epsilon noise

adv_acc6=[0.1985,0.3569,0.4311,0.4620,0.4766,0.4786,0.4824,0.4810]
#rs_fgsm

epsilon=[2,4,6,8,10,12,14,16]

# %%
#cifar100
#adv_acc2=[0.5127,0.3959,0.3201,0.2626,0.2221,0.1881,0.1626,0.1436]

# %%
plt.plot(epsilon,adv_acc1,label="N-FGSM")
plt.plot(epsilon,adv_acc0,label="FGSM")
plt.plot(epsilon,adv_acc2,label="zerograd")
plt.plot(epsilon,adv_acc3,label="multigrad")
plt.plot(epsilon,adv_acc4,label="T_2eps")
plt.plot(epsilon,adv_acc5,label="T_4eps")
plt.plot(epsilon,adv_acc6,label="rs-fgsm")
plt.ylabel('adversarial accuracy')
plt.xlabel('epsilon')
plt.title('cifar10')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
