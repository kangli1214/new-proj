# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
#cifar10
adv_acc1=[0.7931,0.6700,0.5613,0.4818,0.4149,0.3668,0.3259,0.2712]
epsilon=[2,4,6,8,10,12,14,16]

# %%
#cifar100
adv_acc2=[0.5127,0.3959,0.3201,0.2626,0.2221,0.1881,0.1626,0.1436]

# %%
plt.plot(epsilon,adv_acc1)
plt.ylabel('adversarial accuracy')
plt.xlabel('epsilon')
plt.title('cifar10')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(epsilon,adv_acc2)
plt.ylabel('adversarial accuracy')
plt.xlabel('epsilon')
plt.title('cifar100')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
